# %%
# import autosklearn.regression
import sklearn.model_selection
import sklearn.metrics
import os
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFECV
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

from datetime import datetime

# %% [markdown]
# <h4>02 Data Collection</h4>

# %%
df = []
src = r"C:\Users\Acer\Desktop\Hackathon4\farm-connect-soil-water-content-prediction\train\train"
for file in os.listdir(src):
    df.append(pd.read_csv(os.path.join(src,file)))
# for i in df:
#     print(list(i))
df = pd.concat(df)
df = df.fillna(0)
df[-10:]
# Out:
#       index                time  1Air Humidity  1AirTemperature  1LightHigh  \
# 104  12_105  04:40:16.090733+00           44.1             31.2         0.0
# 105  12_106  04:42:16.132055+00           44.2             31.2         0.0
# 106  12_107  04:44:16.107327+00           45.2             30.8         0.0
# 107  12_108   04:46:16.11276+00           45.9             32.0         0.0
# 108  12_109  04:48:16.120498+00           41.4             33.1         0.0
# 109  12_110  04:50:16.123489+00           43.0             33.0         0.0
# 110  12_111  04:52:18.185763+00           42.5             32.5         0.0
# 111  12_112  04:54:16.141528+00           41.7             33.1         0.0
# 112  12_113  04:56:20.078654+00            0.0              0.0         0.0
# 113  12_114  04:58:16.116687+00           44.8             32.5         0.0
#
#      1LightLow  11Rain Accumulate (mm)  11Rain count  12WindSpeed  \
# 104      47.64                     0.0           0.0          0.5
# 105      49.50                     0.0           0.0          0.1
# 106      50.03                     0.0           0.0          1.2
# 107      50.06                     0.0           0.0          0.6
# 108      50.36                     0.0           0.0          0.7
# 109      52.30                     0.0           0.0          1.0
# 110      53.76                     0.0           0.0          0.8
# 111      54.86                     0.0           0.0          0.8
# 112       0.00                     0.0           0.0          0.0
# 113      58.81                     0.0           0.0          1.2
#
#      13WindDirection  23SoilWC ค.ชื้นดิน  23SoilTemp.อุณหภูมิดิน  23SoilEC  \
# 104              3.0                38.8                    22.8      0.11
# 105              1.0                36.9                    22.8      0.11
# 106              7.0                37.4                    22.8      0.11
# 107              1.0                36.9                    22.8      0.11
# 108              7.0                37.6                    22.8      0.11
# 109              5.0                36.9                    22.8      0.11
# 110              4.0                37.4                    22.8      0.11
# 111              4.0                37.4                    22.8      0.11
# 112              2.0                36.9                    22.8      0.11
# 113              7.0                37.4                    22.8      0.11
#
#      23SoilpH   26N   26P   26K  29SoilTension  flow1
# 104       5.0  21.0  95.0  87.0          105.0    0.0
# 105       5.0  21.0  95.0  87.0          111.0    0.0
# 106       5.0  21.0  95.0  87.0          113.0    0.0
# 107       5.0  21.0  95.0  87.0          110.0    0.0
# 108       5.0  21.0  95.0  87.0          108.0    0.0
# 109       5.0  21.0  95.0  87.0          109.0    0.0
# 110       5.0  21.0  95.0  87.0            0.0    0.0
# 111       5.1  21.0  95.0  87.0          109.0    0.0
# 112       5.0  21.0  95.0  87.0          104.0    0.0
# 113       5.1  21.0  95.0  87.0          113.0    0.0

# %%
print(df.shape)
df.columns
# Out:
# (1340, 19)
# Index(['index', 'time', '1Air Humidity', '1AirTemperature', '1LightHigh',
#        '1LightLow', '11Rain Accumulate (mm)', '11Rain count', '12WindSpeed',
#        '13WindDirection', '23SoilWC ค.ชื้นดิน', '23SoilTemp.อุณหภูมิดิน',
#        '23SoilEC', '23SoilpH', '26N', '26P', '26K', '29SoilTension', 'flow1'],
#       dtype='object')

# %%
# Define the function to categorize time of day
def get_time_of_day(hour):
    if 0 <= hour < 5:           # 'Early Morning'
        return 0.0
    elif 5 <= hour < 12:        # 'Morning'
        return 1.0
    elif 12 <= hour < 17:       # 'Afternoon'
        return 2.0
    elif 17 <= hour < 21:       # 'Evening'
        return 3.0
    else:                       # 'Night'
        return 4.0
    
# Convert 'time' column to datetime objects, ignoring the timezone for simplicity
df['time_parsed'] = pd.to_datetime(df['time'].str.split('+').str[0], format='%H:%M:%S.%f')
# Extract hour from the 'time_parsed' column
df['hour'] = df['time_parsed'].dt.hour
# Apply the get_time_of_day function to create 'time_of_day' column
df['time_of_day'] = df['hour'].apply(get_time_of_day)
df['time_of_day'] = df['time_of_day'].astype('float64')
df['hour'] = df['hour'].astype('float64')
# Now df includes the new 'time_of_day' column
# print(df[['time', 'time_of_day']])

# %%
df.describe(include='all')
# Out:
#        index                time  1Air Humidity  1AirTemperature   1LightHigh  \
# count   1340                1340    1340.000000      1340.000000  1340.000000
# unique  1340                1340            NaN              NaN          NaN
# top     01_1  01:00:50.174233+00            NaN              NaN          NaN
# freq       1                   1            NaN              NaN          NaN
# mean     NaN                 NaN      48.565149        28.975373    21.761828
# min      NaN                 NaN       0.000000         0.000000     0.000000
# 25%      NaN                 NaN      41.800000        25.900000     0.000000
# 50%      NaN                 NaN      45.700000        29.600000     0.000000
# 75%      NaN                 NaN      52.725000        32.300000    65.530000
# max      NaN                 NaN      97.300000        38.400000    65.530000
# std      NaN                 NaN      11.594615         4.606203    30.873723
#
#           1LightLow  11Rain Accumulate (mm)  11Rain count  12WindSpeed  \
# count   1340.000000                  1340.0        1340.0  1340.000000
# unique          NaN                     NaN           NaN          NaN
# top             NaN                     NaN           NaN          NaN
# freq            NaN                     NaN           NaN          NaN
# mean      27.479515                     0.0           0.0     0.751045
# min        0.000000                     0.0           0.0     0.000000
# 25%        5.475000                     0.0           0.0     0.100000
# 50%       11.005000                     0.0           0.0     0.600000
# 75%       55.992500                     0.0           0.0     1.100000
# max       65.520000                     0.0           0.0     5.000000
# std       24.924393                     0.0           0.0     0.746727
#
#         13WindDirection  ...     23SoilEC     23SoilpH          26N  \
# count       1340.000000  ...  1340.000000  1340.000000  1340.000000
# unique              NaN  ...          NaN          NaN          NaN
# top                 NaN  ...          NaN          NaN          NaN
# freq                NaN  ...          NaN          NaN          NaN
# mean           2.914179  ...     0.118567     6.512910    20.721642
# min            0.000000  ...     0.000000     0.000000     0.000000
# 25%            1.000000  ...     0.110000     5.000000    21.000000
# 50%            2.000000  ...     0.110000     7.000000    22.000000
# 75%            4.000000  ...     0.120000     7.400000    23.000000
# max            7.000000  ...     0.210000     8.300000    33.000000
# std            2.202777  ...     0.019267     1.240398     7.396645
#
#                 26P          26K  29SoilTension        flow1  \
# count   1340.000000  1340.000000    1340.000000  1340.000000
# unique          NaN          NaN            NaN          NaN
# top             NaN          NaN            NaN          NaN
# freq            NaN          NaN            NaN          NaN
# mean      89.968657    83.330597      40.767164     0.403731
# min        0.000000     0.000000       0.000000     0.000000
# 25%       94.000000    87.000000      23.000000     0.000000
# 50%       97.000000    89.000000      29.000000     0.000000
# 75%      100.000000    93.000000      52.000000     1.000000
# max      123.000000   116.000000     123.000000     1.000000
# std       30.364609    28.248795      31.291224     0.490828
#
#                           time_parsed         hour  time_of_day
# count                            1340  1340.000000  1340.000000
# unique                            NaN          NaN          NaN
# top                               NaN          NaN          NaN
# freq                              NaN          NaN          NaN
# mean    1900-01-01 04:27:40.767920640     3.958955     0.329104
# min        1900-01-01 00:26:03.264438     0.000000     0.000000
# 25%     1900-01-01 02:30:48.188879104     2.000000     0.000000
# 50%     1900-01-01 04:00:46.233681408     4.000000     0.000000
# 75%     1900-01-01 05:37:00.989231360     5.000000     1.000000
# max        1900-01-01 13:03:34.487929    13.000000     2.000000
# std                               NaN     2.702686     0.518417
#
# [11 rows x 22 columns]

# %%
df = df.drop(['index','time','11Rain Accumulate (mm)','11Rain count','time_parsed',],axis=1)

# %% [markdown]
# <hr>

# %% [markdown]
# <h4>03 Exploratory Data Analysis EDA</h4>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1340 entries, 0 to 113
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   1Air Humidity           1340 non-null   float64
#  1   1AirTemperature         1340 non-null   float64
#  2   1LightHigh              1340 non-null   float64
#  3   1LightLow               1340 non-null   float64
#  4   12WindSpeed             1340 non-null   float64
#  5   13WindDirection         1340 non-null   float64
#  6   23SoilWC ค.ชื้นดิน      1340 non-null   float64
#  7   23SoilTemp.อุณหภูมิดิน  1340 non-null   float64
#  8   23SoilEC                1340 non-null   float64
#  9   23SoilpH                1340 non-null   float64
#  10  26N                     1340 non-null   float64
#  11  26P                     1340 non-null   float64
#  12  26K                     1340 non-null   float64
#  13  29SoilTension           1340 non-null   float64
#  14  flow1                   1340 non-null   float64
#  15  hour                    1340 non-null   float64
#  16  time_of_day             1340 non-null   float64
# dtypes: float64(17)
# memory usage: 188.4 KB

# %%
df.describe().T
# Out:
#                          count       mean        std  min     25%     50%  \
# 1Air Humidity           1340.0  48.565149  11.594615  0.0  41.800  45.700
# 1AirTemperature         1340.0  28.975373   4.606203  0.0  25.900  29.600
# 1LightHigh              1340.0  21.761828  30.873723  0.0   0.000   0.000
# 1LightLow               1340.0  27.479515  24.924393  0.0   5.475  11.005
# 12WindSpeed             1340.0   0.751045   0.746727  0.0   0.100   0.600
# 13WindDirection         1340.0   2.914179   2.202777  0.0   1.000   2.000
# 23SoilWC ค.ชื้นดิน      1340.0  34.977164  19.713135  0.0  31.400  36.900
# 23SoilTemp.อุณหภูมิดิน  1340.0  21.970224   1.738520  0.0  21.500  22.000
# 23SoilEC                1340.0   0.118567   0.019267  0.0   0.110   0.110
# 23SoilpH                1340.0   6.512910   1.240398  0.0   5.000   7.000
# 26N                     1340.0  20.721642   7.396645  0.0  21.000  22.000
# 26P                     1340.0  89.968657  30.364609  0.0  94.000  97.000
# 26K                     1340.0  83.330597  28.248795  0.0  87.000  89.000
# 29SoilTension           1340.0  40.767164  31.291224  0.0  23.000  29.000
# flow1                   1340.0   0.403731   0.490828  0.0   0.000   0.000
# hour                    1340.0   3.958955   2.702686  0.0   2.000   4.000
# time_of_day             1340.0   0.329104   0.518417  0.0   0.000   0.000
#
#                              75%     max
# 1Air Humidity            52.7250   97.30
# 1AirTemperature          32.3000   38.40
# 1LightHigh               65.5300   65.53
# 1LightLow                55.9925   65.52
# 12WindSpeed               1.1000    5.00
# 13WindDirection           4.0000    7.00
# 23SoilWC ค.ชื้นดิน       42.5000   80.20
# 23SoilTemp.อุณหภูมิดิน   23.1000   23.70
# 23SoilEC                  0.1200    0.21
# 23SoilpH                  7.4000    8.30
# 26N                      23.0000   33.00
# 26P                     100.0000  123.00
# 26K                      93.0000  116.00
# 29SoilTension            52.0000  123.00
# flow1                     1.0000    1.00
# hour                      5.0000   13.00
# time_of_day               1.0000    2.00

# %%
# # Pair Plot
# sns.pairplot(df)
# plt.show()

# %%
def remove_outliers(df):
    cleaned_data = df.copy()
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            q1 = df[col].quantile(0.25)
            q3 = df[col].quantile(0.75)
            iqr = q3 - q1
            lower_bound = q1 - 1.5 * iqr
            upper_bound = q3 + 1.5 * iqr
            cleaned_data = cleaned_data[(cleaned_data[col] >= lower_bound) & (cleaned_data[col] <= upper_bound)]
    return cleaned_data

# Remove outliers from the dataset
df = remove_outliers(df)
df.describe().T
# Out:
#                         count       mean        std    min      25%    50%  \
# 1Air Humidity           556.0  45.477338   7.901563  32.30  38.9000  45.30
# 1AirTemperature         556.0  28.678597   4.708653  17.70  25.1000  28.90
# 1LightHigh              556.0  33.236439  32.791110   0.00   0.0000  65.53
# 1LightLow               556.0  21.230773  23.616174   0.03   4.4875   8.50
# 12WindSpeed             556.0   0.769424   0.645232   0.00   0.3000   0.60
# 13WindDirection         556.0   3.008993   2.285463   0.00   1.0000   2.00
# 23SoilWC ค.ชื้นดิน      556.0  37.655755   5.749712  29.80  33.2000  36.90
# 23SoilTemp.อุณหภูมิดิน  556.0  21.395504   1.076111  19.90  20.4000  21.50
# 23SoilEC                556.0   0.112212   0.004448   0.11   0.1100   0.11
# 23SoilpH                556.0   7.002518   0.738804   4.80   6.8000   7.10
# 26N                     556.0  21.491007   1.374776  20.00  21.0000  21.00
# 26P                     556.0  96.251799   3.123508  92.00  94.0000  96.00
# 26K                     556.0  88.917266   3.218806  84.00  87.0000  88.00
# 29SoilTension           556.0  27.807554  17.485459   0.00  23.0000  27.00
# flow1                   556.0   0.302158   0.459607   0.00   0.0000   0.00
# hour                    556.0   3.350719   1.909960   0.00   2.0000   3.00
# time_of_day             556.0   0.156475   0.363632   0.00   0.0000   0.00
#
#                            75%     max
# 1Air Humidity           50.500   69.10
# 1AirTemperature         32.025   38.40
# 1LightHigh              65.530   65.53
# 1LightLow               46.370   65.52
# 12WindSpeed              1.200    2.60
# 13WindDirection          5.000    7.00
# 23SoilWC ค.ชื้นดิน      39.700   58.70
# 23SoilTemp.อุณหภูมิดิน  21.900   23.50
# 23SoilEC                 0.110    0.13
# 23SoilpH                 7.400    8.20
# 26N                     22.000   26.00
# 26P                     98.000  106.00
# 26K                     90.000   99.00
# 29SoilTension           30.000   93.00
# flow1                    1.000    1.00
# hour                     4.000    9.00
# time_of_day              0.000    1.00

# %%
# # Pair Plot
# sns.pairplot(df)
# plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# <h4>04 Feature Engineering</h4>

# %%
print(df.columns)
df
# Out:
# Index(['1Air Humidity', '1AirTemperature', '1LightHigh', '1LightLow',
#        '12WindSpeed', '13WindDirection', '23SoilWC ค.ชื้นดิน',
#        '23SoilTemp.อุณหภูมิดิน', '23SoilEC', '23SoilpH', '26N', '26P', '26K',
#        '29SoilTension', 'flow1', 'hour', 'time_of_day'],
#       dtype='object')
#      1Air Humidity  1AirTemperature  1LightHigh  1LightLow  12WindSpeed  \
# 49            48.0             32.3         0.0      62.16          0.0
# 50            45.7             33.0         0.0      61.97          0.0
# 51            44.8             34.4         0.0      62.74          0.0
# 52            45.5             34.4         0.0      63.44          0.0
# 53            47.3             34.2         0.0      63.31          0.0
# ..             ...              ...         ...        ...          ...
# 45            47.4             30.0         0.0      53.43          0.9
# 62            46.9             29.5         0.0      44.12          0.6
# 86            46.3             30.4         0.0      48.35          1.7
# 103           45.0             31.0         0.0      45.51          0.6
# 110           42.5             32.5         0.0      53.76          0.8
#
#      13WindDirection  23SoilWC ค.ชื้นดิน  23SoilTemp.อุณหภูมิดิน  23SoilEC  \
# 49               2.0                58.5                    23.4      0.12
# 50               4.0                57.9                    23.3      0.12
# 51               2.0                53.3                    23.4      0.12
# 52               3.0                52.1                    23.4      0.12
# 53               2.0                52.3                    23.4      0.12
# ..               ...                 ...                     ...       ...
# 45               7.0                49.3                    23.0      0.12
# 62               2.0                42.2                    22.9      0.12
# 86               2.0                37.4                    22.9      0.12
# 103              6.0                36.9                    22.9      0.11
# 110              4.0                37.4                    22.8      0.11
#
#      23SoilpH   26N    26P   26K  29SoilTension  flow1  hour  time_of_day
# 49        7.8  25.0  104.0  97.0           22.0    0.0   2.0          0.0
# 50        7.8  25.0  103.0  96.0           21.0    0.0   2.0          0.0
# 51        7.8  25.0  103.0  96.0           21.0    0.0   2.0          0.0
# 52        7.8  24.0  103.0  96.0           21.0    0.0   2.0          0.0
# 53        7.9  24.0  103.0  96.0           21.0    0.0   2.0          0.0
# ..        ...   ...    ...   ...            ...    ...   ...          ...
# 45        4.9  22.0   97.0  90.0            0.0    1.0   2.0          0.0
# 62        4.9  21.0   96.0  89.0            0.0    0.0   3.0          0.0
# 86        5.0  21.0   95.0  88.0            0.0    0.0   4.0          0.0
# 103       5.0  21.0   95.0  87.0            0.0    0.0   4.0          0.0
# 110       5.0  21.0   95.0  87.0            0.0    0.0   4.0          0.0
#
# [556 rows x 17 columns]

# %%
dfx = df
dfx.corr().style.format("{:.4}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_c5d20_row0_col0, #T_c5d20_row1_col1, #T_c5d20_row2_col2, #T_c5d20_row3_col3, #T_c5d20_row4_col4, #T_c5d20_row5_col5, #T_c5d20_row6_col6, #T_c5d20_row7_col7, #T_c5d20_row8_col8, #T_c5d20_row9_col9, #T_c5d20_row10_col10, #T_c5d20_row11_col11, #T_c5d20_row12_col12, #T_c5d20_row13_col13, #T_c5d20_row14_col14, #T_c5d20_row15_col15, #T_c5d20_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c5d20_row0_col1, #T_c5d20_row1_col0, #T_c5d20_row2_col3, #T_c5d20_row3_col2, #T_c5d20_row4_col1, #T_c5d20_row5_col15, #T_c5d20_row5_col16, #T_c5d20_row6_col0, #T_c5d20_row7_col4, #T_c5d20_row8_col9, #T_c5d20_row9_col13, #T_c5d20_row10_col9, #T_c5d20_row11_col9, #T_c5d20_row12_col9, #T_c5d20_row13_col9, #T_c5d20_row14_col2, #T_c5d20_row15_col0, #T_c5d20_row16_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c5d20_row0_col2, #T_c5d20_row16_col3, #T_c5d20_row16_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c5d20_row0_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c5d20_row0_col4, #T_c5d20_row10_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c5d20_row0_col5, #T_c5d20_row6_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c5d20_row0_col6, #T_c5d20_row12_col16 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c5d20_row0_col7, #T_c5d20_row6_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c5d20_row0_col8, #T_c5d20_row2_col16, #T_c5d20_row3_col16, #T_c5d20_row13_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c5d20_row0_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_c5d20_row0_col10, #T_c5d20_row0_col16, #T_c5d20_row14_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c5d20_row0_col11, #T_c5d20_row3_col15 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_c5d20_row0_col12, #T_c5d20_row6_col9, #T_c5d20_row7_col15, #T_c5d20_row8_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_c5d20_row0_col13, #T_c5d20_row14_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c5d20_row0_col14 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c5d20_row0_col15, #T_c5d20_row5_col6, #T_c5d20_row7_col16, #T_c5d20_row15_col4, #T_c5d20_row16_col13 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c5d20_row1_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_c5d20_row1_col3, #T_c5d20_row2_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c5d20_row1_col4, #T_c5d20_row16_col1, #T_c5d20_row16_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c5d20_row1_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c5d20_row1_col6, #T_c5d20_row3_col10, #T_c5d20_row8_col13 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c5d20_row1_col7 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_c5d20_row1_col8, #T_c5d20_row12_col1, #T_c5d20_row13_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c5d20_row1_col9, #T_c5d20_row9_col7 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c5d20_row1_col10, #T_c5d20_row7_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c5d20_row1_col11 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c5d20_row1_col12 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c5d20_row1_col13 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_c5d20_row1_col14, #T_c5d20_row2_col0, #T_c5d20_row7_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c5d20_row1_col15, #T_c5d20_row3_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_c5d20_row1_col16, #T_c5d20_row2_col4, #T_c5d20_row10_col1, #T_c5d20_row13_col15, #T_c5d20_row15_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_c5d20_row2_col1, #T_c5d20_row3_col11 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_c5d20_row2_col5, #T_c5d20_row15_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c5d20_row2_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c5d20_row2_col7, #T_c5d20_row3_col14, #T_c5d20_row13_col16 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c5d20_row2_col8, #T_c5d20_row4_col16 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c5d20_row2_col9 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c5d20_row2_col11, #T_c5d20_row2_col12, #T_c5d20_row14_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_c5d20_row2_col13, #T_c5d20_row4_col5, #T_c5d20_row10_col15 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c5d20_row2_col14, #T_c5d20_row9_col3, #T_c5d20_row16_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_c5d20_row2_col15 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_c5d20_row3_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c5d20_row3_col1, #T_c5d20_row9_col15 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_c5d20_row3_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c5d20_row3_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c5d20_row3_col6, #T_c5d20_row11_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c5d20_row3_col7, #T_c5d20_row9_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c5d20_row3_col8, #T_c5d20_row13_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c5d20_row3_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c5d20_row3_col12 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c5d20_row4_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c5d20_row4_col2, #T_c5d20_row4_col8, #T_c5d20_row8_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_c5d20_row4_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_c5d20_row4_col6, #T_c5d20_row13_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c5d20_row4_col7, #T_c5d20_row5_col14, #T_c5d20_row11_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c5d20_row4_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_c5d20_row4_col10, #T_c5d20_row13_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c5d20_row4_col11, #T_c5d20_row4_col12, #T_c5d20_row4_col15 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_c5d20_row4_col13 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c5d20_row4_col14, #T_c5d20_row9_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c5d20_row5_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col1, #T_c5d20_row9_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c5d20_row5_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col3, #T_c5d20_row15_col14 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col4, #T_c5d20_row16_col14 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col7, #T_c5d20_row7_col3, #T_c5d20_row7_col5, #T_c5d20_row16_col12 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col8, #T_c5d20_row15_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col9, #T_c5d20_row11_col4, #T_c5d20_row12_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col10 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col11, #T_c5d20_row6_col14 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col12 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c5d20_row5_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c5d20_row6_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c5d20_row6_col3, #T_c5d20_row14_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c5d20_row6_col4, #T_c5d20_row10_col4, #T_c5d20_row14_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c5d20_row6_col5, #T_c5d20_row8_col15, #T_c5d20_row14_col11, #T_c5d20_row14_col12 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_c5d20_row6_col8 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_c5d20_row6_col10, #T_c5d20_row8_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c5d20_row6_col11, #T_c5d20_row8_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_c5d20_row6_col12 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_c5d20_row6_col13 {
#   background

# %%
feature_sort = dict(dfx.corr()['23SoilWC ค.ชื้นดิน'])
sorted_x = dict(sorted(feature_sort.items(), key=lambda item: item[-1],reverse=True))
sorted_x
# Out:
# {'23SoilWC ค.ชื้นดิน': 1.0,
#  '23SoilEC': 0.5281081566437361,
#  '26P': 0.41420988666284797,
#  '26K': 0.4016029577965687,
#  '1AirTemperature': 0.39004364171796796,
#  '26N': 0.3414103062207534,
#  '23SoilTemp.อุณหภูมิดิน': 0.2570289511234114,
#  '1LightLow': 0.18762615074765268,
#  '23SoilpH': 0.13691602826742844,
#  '1LightHigh': 0.13137198941400632,
#  '13WindDirection': 0.11166979877548296,
#  'time_of_day': -0.02951674321066998,
#  'hour': -0.031398999810761816,
#  '12WindSpeed': -0.08021495660255422,
#  '29SoilTension': -0.20492669732133947,
#  'flow1': -0.25150346711170646,
#  '1Air Humidity': -0.31744692959066034}

# %%
print(list(sorted_x.keys())[1:])
# Out:
# ['23SoilEC', '26P', '26K', '1AirTemperature', '26N', '23SoilTemp.อุณหภูมิดิน', '1LightLow', '23SoilpH', '1LightHigh', '13WindDirection', 'time_of_day', 'hour', '12WindSpeed', '29SoilTension', 'flow1', '1Air Humidity']

# %% [markdown]
# <h5>Feature  selectin</h5>

# %%
# X = dfx[['1Air Humidity', '1AirTemperature', '1LightHigh',
#                 '1LightLow','12WindSpeed',
#                 '23SoilEC', '23SoilpH', '23SoilTemp.อุณหภูมิดิน',  '26N', '26P', '26K',
#                 '29SoilTension', 'flow1']]

# X = dfx[['26P', '26K', '26N', '1AirTemperature', '23SoilTemp.อุณหภูมิดิน','23SoilpH', '1LightLow', 'time_of_day']]   
# X = dfx[['23SoilEC', '26P', '26K', '1AirTemperature', '23SoilpH', '1LightLow']]       
# X = dfx[['23SoilEC', '26P', '26K', '1AirTemperature', '23SoilpH', '1LightLow','time_of_day']]                                                   
# X = dfx[['23SoilEC','26P','26K','26N','1AirTemperature','23SoilTemp.อุณหภูมิดิน','23SoilpH','1LightLow']]                                          
# X = dfx[['23SoilEC','26P','26K','26N','1AirTemperature','23SoilTemp.อุณหภูมิดิน','23SoilpH','1LightLow','time_of_day']]  
                          
# X = dfx[['23SoilEC', '26P', '26K', '1AirTemperature', '26N', '23SoilTemp.อุณหภูมิดิน', '1LightLow', '23SoilpH', '1LightHigh', '13WindDirection', 'time_of_day', 'hour']]   # 1 rfr_mae->min:0.84558 avg:0.88921
X = dfx[['23SoilEC', '26P', '26K', '1AirTemperature', '26N', '23SoilTemp.อุณหภูมิดิน', '1LightLow', '23SoilpH', '1LightHigh', '13WindDirection','hour']]                 #   rfr_mae->min:0.82709 avg:0.89503

y = df[['23SoilWC ค.ชื้นดิน']]

# %% [markdown]
# <hr>
# <hr>
# <hr>

# %%
X
# Out:
#      23SoilEC    26P   26K  1AirTemperature   26N  23SoilTemp.อุณหภูมิดิน  \
# 49       0.12  104.0  97.0             32.3  25.0                    23.4
# 50       0.12  103.0  96.0             33.0  25.0                    23.3
# 51       0.12  103.0  96.0             34.4  25.0                    23.4
# 52       0.12  103.0  96.0             34.4  24.0                    23.4
# 53       0.12  103.0  96.0             34.2  24.0                    23.4
# ..        ...    ...   ...              ...   ...                     ...
# 45       0.12   97.0  90.0             30.0  22.0                    23.0
# 62       0.12   96.0  89.0             29.5  21.0                    22.9
# 86       0.12   95.0  88.0             30.4  21.0                    22.9
# 103      0.11   95.0  87.0             31.0  21.0                    22.9
# 110      0.11   95.0  87.0             32.5  21.0                    22.8
#
#      1LightLow  23SoilpH  1LightHigh  13WindDirection  hour
# 49       62.16       7.8         0.0              2.0   2.0
# 50       61.97       7.8         0.0              4.0   2.0
# 51       62.74       7.8         0.0              2.0   2.0
# 52       63.44       7.8         0.0              3.0   2.0
# 53       63.31       7.9         0.0              2.0   2.0
# ..         ...       ...         ...              ...   ...
# 45       53.43       4.9         0.0              7.0   2.0
# 62       44.12       4.9         0.0              2.0   3.0
# 86       48.35       5.0         0.0              2.0   4.0
# 103      45.51       5.0         0.0              6.0   4.0
# 110      53.76       5.0         0.0              4.0   4.0
#
# [556 rows x 11 columns]

# %%
y
# Out:
#      23SoilWC ค.ชื้นดิน
# 49                 58.5
# 50                 57.9
# 51                 53.3
# 52                 52.1
# 53                 52.3
# ..                  ...
# 45                 49.3
# 62                 42.2
# 86                 37.4
# 103                36.9
# 110                37.4
#
# [556 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.074, random_state = 99)
X_train.shape, X_test.shape
# Out:
# ((514, 11), (42, 11))

# %% [markdown]
# <h5>Scaleing?</h5>

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
# X_train = X_train_scaled
# X_test  = X_test_scaled

# %%
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.metrics import mean_absolute_error
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# X_train = X_train_scaled
# X_test  = X_test_scaled

# knn_param_grid = {
#     'n_neighbors': [3, 5, 7],
#     'weights': ['uniform', 'distance'],
#     'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
# }
# knn_grid_search = GridSearchCV(KNeighborsRegressor(), knn_param_grid, cv=5, scoring='neg_mean_absolute_error')
# knn_grid_search.fit(X_train, y_train)
# knn_best = knn_grid_search.best_estimator_
# knn_predictions = knn_best.predict(X_test)
# knn_mae = mean_absolute_error(y_test, knn_predictions)
# print(f'KNN Regression MAE: {knn_mae}, Best Params: {knn_grid_search.best_params_}')

# %%
# dt_best.predict(X_test)

# %% [markdown]
# <hr>

# %% [markdown]
# <h4>05 Model Selection</h4>

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import BayesianRidge
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error


from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, DotProduct
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from pygam import LinearGAM, s, f
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <hr>
# <hr>

# %% [markdown]
# <h4>06 Model Training</h4>

# %%
x = []
src2 = r"C:\Users\Acer\Desktop\Hackathon4\farm-connect-soil-water-content-prediction\test\test"
for file in os.listdir(src2):
    print(os.path.join(src2,file))
    x.append(pd.read_csv(os.path.join(src2,file)))
x = pd.concat(x)
x = x.fillna(0)

# Define the function to categorize time of day
def get_time_of_day(hour):
    if 0 <= hour < 5:           # 'Early Morning'
        return 0.0
    elif 5 <= hour < 12:        # 'Morning'
        return 1.0
    elif 12 <= hour < 17:       # 'Afternoon'
        return 2.0
    elif 17 <= hour < 21:       # 'Evening'
        return 3.0
    else:                       # 'Night'
        return 4.0

# Convert 'time' column to datetime objects, ignoring the timezone for simplicity
x['time_parsed'] = pd.to_datetime(x['time'].str.split('+').str[0], format='%H:%M:%S.%f')

# Extract hour from the 'time_parsed' column
x['hour'] = x['time_parsed'].dt.hour

# Apply the get_time_of_day function to create 'time_of_day' column
x['time_of_day'] = x['hour'].apply(get_time_of_day)

x['time_of_day'] = x['time_of_day'].astype('float64')
x['hour'] = x['hour'].astype('float64')
# Now x includes the new 'time_of_day' column
# print(x[['time', 'time_of_day']])
x = x.drop(['index','time','11Rain Accumulate (mm)','11Rain count','time_parsed',],axis=1)
# Out:
# C:\Users\Acer\Desktop\Hackathon4\farm-connect-soil-water-content-prediction\test\test\set02.csv
# C:\Users\Acer\Desktop\Hackathon4\farm-connect-soil-water-content-prediction\test\test\set09.csv

# %%
x = x[X.columns]
x
# Out:
#      23SoilEC    26P    26K  1AirTemperature   26N  23SoilTemp.อุณหภูมิดิน  \
# 0        0.11   95.0   88.0             30.7  21.0                    22.4
# 1        0.11   95.0   88.0             31.4  21.0                    22.4
# 2        0.11   95.0   88.0             32.2  21.0                    22.3
# 3        0.11   95.0   88.0             33.0  21.0                    22.4
# 4        0.11   95.0   88.0             32.9  21.0                    22.4
# ..        ...    ...    ...              ...   ...                     ...
# 111      0.12  110.0  103.0             35.9  27.0                    23.7
# 112      0.12  110.0  103.0             35.9  27.0                    23.7
# 113      0.12  110.0  103.0             35.8  27.0                    23.7
# 114      0.12  110.0  103.0             35.6  27.0                    23.7
# 115      0.12  110.0  103.0             36.4  27.0                    23.7
#
#      1LightLow  23SoilpH  1LightHigh  13WindDirection  hour
# 0         8.79       7.9       65.53              2.0   4.0
# 1         8.26       7.9       65.53              1.0   4.0
# 2         8.66       7.9       65.53              2.0   4.0
# 3         8.68       7.9       65.53              2.0   4.0
# 4         8.86       7.9       65.53              2.0   4.0
# ..         ...       ...         ...              ...   ...
# 111      53.35       4.9        0.00              3.0   7.0
# 112      54.13       4.9        0.00              0.0   7.0
# 113      54.11       4.9        0.00              1.0   7.0
# 114      54.26       4.9        0.00              1.0   7.0
# 115      53.95       4.9        0.00              3.0   7.0
#
# [229 rows x 11 columns]

# %%
def model1():
    dt_param_grid = {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 10, 20]
    }
    dt_grid_search = GridSearchCV(DecisionTreeRegressor(), dt_param_grid, cv=5, scoring='neg_mean_absolute_error')
    dt_grid_search.fit(X_train, y_train)
    dt_best = dt_grid_search.best_estimator_
    dt_predictions = dt_best.predict(X_test)
    dt_mae = mean_absolute_error(y_test, dt_predictions)
    # print(f'Decision Tree MSE: {dt_mae}, Best Params: {dt_grid_search.best_params_}')
    return dt_mae,dt_best
def model2():
    rfr = RandomForestRegressor()
    rfr_param_grid = {
        'n_estimators': [10,50, 100, 200],
        'max_depth': [None,2, 5, 10,20],
        'min_samples_split':[2,5,10],
        'min_samples_leaf':[1,4],
        'max_features':['auto','sqrt','log2']
    }
    rfr_grid_search = GridSearchCV(rfr, rfr_param_grid, cv=5, scoring='neg_mean_absolute_error')
    rfr_grid_search.fit(X_train, y_train)
    rfr_best = rfr_grid_search.best_estimator_
    rfr_predictions = rfr_best.predict(X_test)
    rfr_mae = mean_absolute_error(y_test, rfr_predictions)
    # print("Random Forest Regressor mae:", rfr_mae)
    return rfr_mae,rfr_best
def model3():
    xgb_param_grid = {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 6, 9]
    }
    xgb_grid_search = GridSearchCV(xgb.XGBRegressor(), xgb_param_grid, cv=5, scoring='neg_mean_absolute_error')
    xgb_grid_search.fit(X_train, y_train)
    xgb_best = xgb_grid_search.best_estimator_
    xgb_predictions = xgb_best.predict(X_test)
    xgb_mae = mean_absolute_error(y_test, xgb_predictions)
    # print(f'XGBoost MSE: {xgb_mae}, Best Params: {xgb_grid_search.best_params_}')
    return xgb_mae,xgb_best

def model4():
    gbrt = GradientBoostingRegressor()
    gbrt_param_grid = {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.05, 0.1, 0.2]
        }
    gbrt_grid_search = GridSearchCV(gbrt, gbrt_param_grid, cv=5, scoring='neg_mean_absolute_error')
    gbrt_grid_search.fit(X_train, y_train)
    gbrt_best = gbrt_grid_search.best_estimator_
    gbrt_predictions = gbrt_best.predict(X_test)
    gbrt_mae = mean_absolute_error(y_test, gbrt_predictions)
    return gbrt_mae,gbrt_best
def model5():
    lgb_param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth':[3, 6, 9, -1],
        'num_leaves': [31, 62, 127, 255]
    }
    lgb_grid_search = GridSearchCV(lgb.LGBMRegressor(), lgb_param_grid, cv=5, scoring='neg_mean_absolute_error')
    lgb_grid_search.fit(X_train, y_train)
    lgb_best = lgb_grid_search.best_estimator_
    lgb_predictions = lgb_best.predict(X_test)
    lgb_mae = mean_absolute_error(y_test, lgb_predictions)
    return lgb_mae,lgb_best
def model6():
    knn_param_grid = {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    }
    knn_grid_search = GridSearchCV(KNeighborsRegressor(), knn_param_grid, cv=5, scoring='neg_mean_absolute_error')
    scaler = StandardScaler()
    knn_grid_search.fit(scaler.fit_transform(X_train), y_train)
    knn_best = knn_grid_search.best_estimator_
    # print("Use: X_test_scaled = scaler.transform(X_test) ")
    knn_predictions = knn_best.predict(scaler.transform(X_test))
    knn_mae = mean_absolute_error(y_test, knn_predictions)
    print(knn_mae)
    return knn_mae,knn_best
def model7():
    param_grid = {
            "colsample_bytree": [0.3, 0.4, 0.5],
            "gamma": [0],
            "learning_rate": [0.4, 0.5, 0.6],
            "max_depth": [1, 2, 3],
            "reg_lambda": [11, 12, 13],
            "scale_pos_weight": [0],
            "subsample": [0.4, 0.5, 0.6],
    }
    grid_cv = xgb.XGBRegressor()
    grid_cv = GridSearchCV(
        grid_cv,
        param_grid,
        n_jobs=-1,
        cv=3,
        scoring='neg_mean_absolute_error'
    )
    grid_cv.fit(X_train, y_train)
    grid_cv.best_params_
    y_hat = grid_cv.predict(X_test)
    xbbl_mae = mean_absolute_error(y_test, y_hat)
    return xbbl_mae,grid_cv
def model8():
    rf = RandomForestRegressor()
    rf.fit(X_train,y_train)
    rf_baseline = rf.predict(X_test)
    rfbl_mae = mean_absolute_error(y_test, rf_baseline)
    return rfbl_mae,rf
# def model9():
#     nn_param_grid = {
#         'hidden_layer_sizes': [(50,), (100,), (50,50)],
#         'activation': ['relu', 'tanh', 'logistic'],
#         'solver': ['adam', 'lbfgs']
#     }
#     scaler = StandardScaler().fit(X_train)
#     X_train_scaled = scaler.transform(X_train)
#     X_test_scaled = scaler.transform(X_test)
#     nn_grid_search = GridSearchCV(MLPRegressor(max_iter=1000), nn_param_grid, cv=5, scoring='neg_mean_absolute_error')
#     nn_grid_search.fit(X_train_scaled, y_train)
#     nn_best = nn_grid_search.best_estimator_
#     nn_predictions = nn_best.predict(X_test_scaled)
#     nn_mae = mean_absolute_error(y_test, nn_predictions)
#     return nn_mae,nn_best
res = {
    'dt_mae':[],
    'rfr_mae':[],
    'xgb_mae':[],
    'gbrt_mae':[],
    'lgb_mae':[],
    'knn_mae':[],
    'xbbl_mae':[],
    'rfbl_mae':[],
    # 'nn_mae':[]
}

Ex_mae = 2
for _ in range(5):
    # dt_mae,bmodel1  = model1()
    # if dt_mae<Ex_mae:
    #     Ex_mae = dt_mae
    #     best_model = bmodel1
    # res['dt_mae'].append(dt_mae)

    rfr_mae,bmodel2 = model2()
    if rfr_mae<Ex_mae:
        Ex_mae = rfr_mae
        best_model = bmodel2
    print(rfr_mae)
    res['rfr_mae'].append(rfr_mae)

    # xgb_mae,bmodel3 = model3()
    # if xgb_mae<Ex_mae:
    #     Ex_mae = xgb_mae
    #     best_model = bmodel3
    # res['xgb_mae'].append(xgb_mae)

    # gbrt_mae,bmodel4 = model4()
    # if gbrt_mae<Ex_mae:
    #     Ex_mae = gbrt_mae
    #     best_model = bmodel4
    # res['gbrt_mae'].append(gbrt_mae)

    # lgb_mae,bmodel5 = model5()
    # if lgb_mae<Ex_mae:
    #     Ex_mae = lgb_mae
    #     best_model = bmodel5
    # res['lgb_mae'].append(lgb_mae)    
    
    # knn_mae,bmodel6 = model6()
    # if knn_mae<Ex_mae:
    #     Ex_mae = knn_mae
    #     best_model = bmodel6
    # res['knn_mae'].append(knn_mae)    
    
    # xbbl_mae,bmodel7 = model7()
    # if xbbl_mae<Ex_mae:
    #     Ex_mae = xbbl_mae
    #     best_model = bmodel7
    # res['xbbl_mae'].append(xbbl_mae)    
    
    # rfbl_mae,bmodel8 = model8()
    # if rfbl_mae<Ex_mae:
    #     Ex_mae = rfbl_mae
    #     best_model = bmodel8
    # res['rfbl_mae'].append(rfbl_mae)
# Out:
# 0.7213695887445892
# 0.7029523809523733

# %%
print(f"rfr_mae->min:{Ex_mae:.05f} avg:{sum(res['rfr_mae'])/len(res['rfr_mae']):.05f}")
# Out:
# rfr_mae->min:0.68792 avg:0.75181

# %%
# performance testing
Yy = best_model.predict(X_test)
mae = mean_absolute_error(y_test, Yy)
print(mae)
# Out:
# 0.6879183201058152

# %%
# x_scaled = best_scaler.transform(x)  # Use the best scaler here
y = best_model.predict(x)
# y = y.flatten()
y
# Out:
# array([36.958  , 36.927  , 36.8885 , 36.9465 , 36.9465 , 37.0235 ,
#        36.895  , 36.8675 , 36.938  , 36.9275 , 36.9125 , 37.014  ,
#        36.9545 , 36.9765 , 36.955  , 37.4065 , 37.4194 , 43.003  ,
#        44.403  , 44.514  , 45.6815 , 45.59   , 45.438  , 45.686  ,
#        46.612  , 46.454  , 47.067  , 46.7665 , 46.804  , 34.9725 ,
#        45.9035 , 34.917  , 47.9275 , 48.866  , 49.3145 , 48.7385 ,
#        45.314  , 45.212  , 43.706  , 43.8925 , 35.512  , 43.77   ,
#        43.733  , 43.729  , 45.164  , 43.361  , 43.6455 , 44.03   ,
#        35.1925 , 43.602  , 43.6225 , 48.0275 , 47.99   , 46.504  ,
#        47.1865 , 46.2735 , 45.9625 , 46.1995 , 46.15   , 46.913  ,
#        35.0735 , 46.516  , 32.211  , 39.6785 , 39.547  , 32.242  ,
#        39.4489 , 39.4514 , 39.4954 , 39.7004 , 39.5474 , 39.5879 ,
#        39.8294 , 39.9144 , 39.8414 , 39.8114 , 39.611  , 32.394  ,
#        39.6889 , 39.3744 , 39.3949 , 38.8144 , 38.8234 , 38.8574 ,
#        38.7749 , 38.8089 , 38.8215 , 39.2139 , 39.1269 , 39.2004 ,
#        39.3414 , 39.2189 , 32.4625 , 39.3059 , 38.8465 , 38.818  ,
#        38.801  , 39.2864 , 32.808  , 32.6955 , 32.6595 , 38.8105 ,
#        38.792  , 38.8175 , 38.814  , 38.8145 , 38.7615 , 38.852  ,
#        38.9865 , 38.637  , 38.7335 , 38.938  , 38.864  , 39.622  ,
#        39.742  , 39.59225, 39.416  , 34.1975 , 34.2885 , 39.503  ,
#        39.302  , 39.204  , 39.1065 , 39.336  , 39.2805 , 39.287  ,
#        39.3055 , 38.4915 , 38.549  , 34.009  , 38.516  , 38.396  ,
#        38.418  , 38.4285 , 38.584  , 38.558  , 38.7115 , 38.528  ,
#        38.598  , 38.4845 , 38.5315 , 38.539  , 34.0185 , 39.149  ,
#        39.126  , 40.277  , 40.4555 , 39.193  , 39.1675 , 39.1095 ,
#        38.973  , 38.9405 , 38.948  , 39.0315 , 38.932  , 34.0125 ,
#        39.053  , 39.1805 , 38.9995 , 38.1025 , 38.192  , 38.1245 ,
#        39.0595 , 38.241  , 38.156  , 39.284  , 38.046  , 38.5665 ,
#        38.4845 , 38.429  , 38.3525 , 38.4    , 38.3285 , 38.518  ,
#        38.326  , 38.3685 , 36.2525 , 38.4685 , 36.3575 , 38.536  ,
#        38.536  , 38.4155 , 38.231  , 38.4475 , 38.3045 , 38.356  ,
#        38.4575 , 39.62   , 39.1945 , 38.894  , 38.8275 , 38.569  ,
#        38.828  , 38.6455 , 38.8725 , 38.6815 , 38.8355 , 38.7995 ,
#        38.5975 , 38.623  , 38.8075 , 38.8015 , 38.891  , 38.934  ,
#        36.4425 , 36.3235 , 42.01   , 39.517  , 42.0395 , 42.21   ,
#        41.7315 , 41.8865 , 41.819  , 42.0275 , 42.1295 , 42.0755 ,
#        41.289  , 42.014  , 42.31   , 42.0135 , 42.0575 , 42.0785 ,
#        41.7975 , 42.0615 , 42.0765 , 41.82   , 41.7845 , 41.7845 ,
#        42.0765 ])

# %% [markdown]
# <hr>

# %% [markdown]
# <h4>07 Create CSV</h4>

# %%
submission = pd.read_csv(r"C:\Users\Acer\Desktop\Hackathon4\farm-connect-soil-water-content-prediction\sample_submission.csv")
submission['23SoilWC ค.ชื้นดิน'].iloc[1:] = y[1:]
submission
# Out:
#       index  23SoilWC ค.ชื้นดิน
# 0      02_1             31.1000
# 1      02_2             36.9270
# 2      02_3             36.8885
# 3      02_4             36.9465
# 4      02_5             36.9465
# ..      ...                 ...
# 224  09_112             42.0765
# 225  09_113             41.8200
# 226  09_114             41.7845
# 227  09_115             41.7845
# 228  09_116             42.0765
#
# [229 rows x 2 columns]

# %%
# performance testing
Yy = best_model.predict(X_test)
mae = mean_absolute_error(y_test, Yy)
print(mae)
# Out:
# 0.6879183201058152

# %%
0/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 0/0
#
# ZeroDivisionError: division by zero

# %%
submission.to_csv('0.68051.csv',index=False)
